# %% [markdown]
# ![image.png](attachment:a3bef8d1-9599-4b36-917a-9af371575dc0.png)

# %%
PSEUDOCODE FOR STORE CHECKOUT AFTER PURCHASE 

BEGIN
Input items
total = 0 
FOR each item 
    scan item 
    total = total + item price 
END FOR 
Display total amount 
Input payment 
IF payment >= total THEN 
    print receipt 
    give change if necessary 
    display "Thank you for shopping"
ELSE 
    display "Payment unsuccessful"
END IF 
END

# %% [markdown]
# ![image.png](attachment:e131af55-ab91-4308-a476-4cea242fdd6f.png)

# %%
Algorithm for Swapping ages 

START
Input the first name 
Input the first age 
Input the second name 
Input the second age 
Store the first age in a temporary variable 
Replace the first age with the second age 
Replace the second age with the temporary value 
Display the new ages of both people 
END
# Out:
#   Cell In[1], line 1
#     Algorithm for Swapping ages
#               ^
# SyntaxError: invalid syntax
