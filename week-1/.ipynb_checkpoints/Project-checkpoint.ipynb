# %%
# Simple Interest Calculator
P = float(input("Enter Principal: "))
R = float(input("Enter Rate: "))
T = float(input("Enter Time: "))
SI = (P * R * T) / 100
print("Simple Interest =", SI)
# Out:
# Enter Principal:  45344
# Enter Rate:  34
# Enter Time:  3
# Simple Interest = 46250.88

# %% [markdown]
# ![image.png](attachment:9a97921e-82a4-4d49-bc11-5591c910a5e3.png)

# %%
# Compound Interest Calculator
P = float(input("Enter Principal: "))
R = float(input("Enter Rate: "))
T = float(input("Enter Time: "))
A = P * (1 + R/100) ** T
print("Compound Amount =", A)
# Out:
# Enter Principal:  9584
# Enter Rate:  4
# Enter Time:  4
# Compound Amount = 11211.924439040002

# %% [markdown]
# ![image.png](attachment:e26b3d04-bdde-4488-83c3-7fa1a60be8f2.png)

# %%
# Annuity Plan Calculator 
PMT = float(input("Enter Payment Amount: "))
R = float(input("Enter Interest Rate: "))
n = float(input("Enter Number of payments per year: "))
t = float(input("Enter number of years: "))
A = PMT * ((1 + R/n) ** (n*t) - 1) / (R/n)
print("Value of Annuity =", A)
# Out:
# Enter Payment Amount:  78576
# Enter Interest Rate:  8
# Enter Number of payments per year:  4
# Enter number of years:  4
# Value of Annuity = 1691219535360.0

# %% [markdown]
# ![image.png](attachment:b3adb512-cf30-4a16-bdaa-b199795163ed.png)
